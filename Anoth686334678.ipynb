# %% [markdown]
# <a href="https://colab.research.google.com/github/lourish789/Quizlet/blob/main/Anoth686334678.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 21.2 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from datasets import load_dataset

# %%
# !pip install scikit-learn

# %%
# Load the dataset
import requests
import pandas as pd
from datasets import Dataset, DatasetDict

# Fetch data from the API
response = requests.get('https://opentdb.com/api.php?amount=10')
data = response.json()['results']

# Convert the JSON data to a pandas DataFrame
df = pd.DataFrame(data)

# Create a Dataset from the DataFrame
dataset = Dataset.from_pandas(df)

# Create a DatasetDict with just the 'train' split
dataset = DatasetDict({'train': dataset})

# Now you can proceed with the rest of your code using the 'dataset' object

#dataset = load_dataset('csv', data_files={'train': 'https://opentdb.com/api.php?amount=10'}) #'validation': 'validation.csv'})

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from datasets import load_dataset, DatasetDict, Dataset # Import Dataset here
from sklearn.model_selection import train_test_split

# Load the dataset
#dataset = load_dataset('csv', data_files={'train': '/content/EE_CSV_quiz_questions.csv'})

# Convert the dataset to pandas DataFrame for train_test_split
df = dataset['train'].to_pandas()

# Split the train dataset into train and validation using the DataFrame
train_data, validation_data = train_test_split(df, test_size=0.2, random_state=42)  # Adjust test_size as needed

# Convert the train and validation DataFrames back to Dataset objects
train_dataset = Dataset.from_pandas(train_data) # Now Dataset is defined
validation_dataset = Dataset.from_pandas(validation_data)

# Create a DatasetDict with train and validation splits
dataset = DatasetDict({
    'train': train_dataset,
    'validation': validation_dataset
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-912101b173e1> in <cell line: 0>()
#      14
#      15 # Convert the train and validation DataFrames back to Dataset objects
# ---> 16 train_dataset = Dataset.from_pandas(train_data) # Now Dataset is defined
#      17 validation_dataset = Dataset.from_pandas(validation_data)
#      18
#
# /usr/local/lib/python3.11/dist-packages/datasets/arrow_dataset.py in from_pandas(cls, df, features, info, split, preserve_index)
#     852             # needed to support the str to Audio conversion for instance
#     853             table = table.cast(features.arrow_schema)
# --> 854         return cls(table, info=info, split=split)
#     855
#     856     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/datasets/arrow_dataset.py in __init__(self, arrow_table, info, split, indices_table, fingerprint)
#     680
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
from datasets import load_dataset, DatasetDict, Dataset # Import Dataset here
from sklearn.model_selection import train_test_split

# Load the dataset
#dataset = load_dataset('csv', data_files={'train': '/content/EE_CSV_quiz_questions.csv'})

# Convert the dataset to pandas DataFrame for train_test_split
df = dataset['train'].to_pandas()

# Split the train dataset into train and validation using the DataFrame
train_data, validation_data = train_test_split(df, test_size=0.2, random_state=42)  # Adjust test_size as needed

# Reset the index of the split DataFrames
train_data = train_data.reset_index(drop=True) # Reset index and drop the old index column
validation_data = validation_data.reset_index(drop=True) # Reset index and drop the old index column


# Convert the train and validation DataFrames back to Dataset objects
train_dataset = Dataset.from_pandas(train_data) # Now Dataset is defined
validation_dataset = Dataset.from_pandas(validation_data)

# Create a DatasetDict with train and validation splits
dataset = DatasetDict({
    'train': train_dataset,
    'validation': validation_dataset
})

# Initialize the tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token  # or '[PAD]' if you want a different token
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Tokenize the dataset
def tokenize_function(examples):
    return tokenizer(examples['question'], padding='max_length', truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]

# %%
dataset['train'][:5]
# Out:
# {'type': ['multiple', 'multiple', 'boolean', 'multiple'],
#  'difficulty': ['medium', 'easy', 'medium', 'easy'],
#  'category': ['History',
#   'Entertainment: Japanese Anime &amp; Manga',
#   'Sports',
#   'Entertainment: Comics'],
#  'question': ['The Tsar Bomba, the most powerful nuclear bomb ever tested, had a yield of 50 megatons but theoretically had a maximum yield of how much?',
#   'In the anime Seven Deadly Sins what is the name of one of the sins?',
#   'The Olympics tennis court is a giant green screen.',
#   'Who is Batman?'],
#  'correct_answer': ['100 Megatons', 'Diane', 'True', 'Bruce Wayne'],
#  'incorrect_answers': [['200 Megatons', '75 Megatons', '150 Megatons'],
#   ['Sakura', 'Ayano', 'Sheska'],
#   ['False'],
#   ['Clark Kent', 'Barry Allen', 'Tony Stark']],
#  '__index_level_0__': [3, 7, 2, 9]}

# %%
# Initialize the tokenizer and model
#tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
#model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
# Tokenize the dataset
#def tokenize_function(examples):
 #   return tokenizer(examples['Question text'], padding='max_length', truncation=True)

# %%
# Initialize the tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# Add the padding token to the tokenizer
tokenizer.pad_token = tokenizer.eos_token # or '[PAD]' if you want a different token

model = GPT2LMHeadModel.from_pretrained('gpt2')

# Tokenize the dataset
# Tokenize the dataset
#def tokenize_function(examples):
   # return tokenizer(examples['question'], padding='max_length', truncation=True, return_labels=True)  # Added return_labels=True
    #return tokenizer(examples['question'], padding='max_length', truncation=True)

#tokenized_datasets = dataset.map(tokenize_function, batched=True)
#def tokenize_function(examples):
 #   return tokenizer(examples['Question text'], padding='max_length', truncation=True)
# Out:
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Keyword arguments {'return_labels': True} not recognized.
# Keyword arguments {'return_labels': True} not recognized.
# Keyword arguments {'return_labels': True} not recognized.
# Keyword arguments {'return_labels': True} not recognized.
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Keyword arguments {'return_labels': True} not recognized.
# Keyword arguments {'return_labels': True} not recognized.

# %%
# Tokenize the dataset
def tokenize_function(examples):
    # Tokenize the input text and create labels
    tokenized_output = tokenizer(examples['question'], padding='max_length', truncation=True)
    # Set labels to the input IDs shifted to the right by one position
    # This is how causal language modeling is done with the Trainer
    tokenized_output['labels'] = tokenized_output['input_ids'].copy()
    # Replace padding token IDs with -100 so they are ignored in loss calculation
    tokenized_output['labels'] = [
        [-100 if token == tokenizer.pad_token_id else token for token in labels]
        for labels in tokenized_output['labels']
    ]
    return tokenized_output

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]

# %%
#tokenized_datasets = dataset.map(tokenize_function, batched=True)

# %%
# Set training arguments
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=2,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation'],
)

# %%
# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:16, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.691796</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>3.679105</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>3.675843</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6, training_loss=3.1146767934163413, metrics={'train_runtime': 17.0563, 'train_samples_per_second': 0.704, 'train_steps_per_second': 0.352, 'total_flos': 6271008768000.0, 'train_loss': 3.1146767934163413, 'epoch': 3.0})

# %%
def generate_question(topic, difficulty, num_questions):
    prompt = f"Generate {num_questions} {difficulty} level questions on {topic}:\n"
    inputs = tokenizer(prompt, return_tensors='pt')
    outputs = model.generate(**inputs, max_length=150, num_return_sequences=num_questions)
  #  questions = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return questions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7d58114913d5> in <cell line: 0>()
#       7
#       8 # Example usage
# ----> 9 questions = generate_question('Thermodynamics', 'medium', 5)
#      10 for i, question in enumerate(questions, 1):
#      11     print(f"Q{i}: {question}\n")
#
# <ipython-input-27-7d58114913d5> in generate_question(topic, difficulty, num_questions)
#       2     prompt = f"Generate {num_questions} {difficulty} level questions on {topic}:\n"
#       3     inputs = tokenizer(prompt, return_tensors='pt')
# ----> 4     outputs = model.generate(**inputs, max_length=150, num_return_sequences=num_questions)
#       5     questions = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
#       6     return questions
#
# ...

# %%
def generate_question(topic, difficulty, num_questions):
    prompt = f"Generate {num_questions} {difficulty} level questions on {topic}:\n"
    inputs = tokenizer(prompt, return_tensors='pt')
    # Use beam search with num_beams=num_questions to generate multiple sequences
    outputs = model.generate(**inputs, max_length=150, num_beams=num_questions, num_return_sequences=num_questions)
    questions = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return questions

# %%
def generate_question(topic, difficulty, num_questions):
    prompt = f"Generate {num_questions} {difficulty} level questions on {topic}:\n"
    inputs = tokenizer(prompt, return_tensors='pt')

    # Move inputs to the same device as the model
    if torch.cuda.is_available():
        inputs = inputs.to(model.device) # Move inputs to GPU if available

    # Use beam search with num_beams=num_questions to generate multiple sequences
    outputs = model.generate(**inputs, max_length=150, num_beams=num_questions, num_return_sequences=num_questions)
    questions = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return questions

# %%
# Example usage
questions = generate_question('Thermodynamics', 'medium', 5)
for i, question in enumerate(questions, 1):
    print(f"Q{i}: {question}\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Q1: Generate 5 medium level questions on Thermodynamics:
#
# 1. What is a Thermodynamic Unit?
#
# 2. What is a Thermodynamic Unit?
#
# 3. What is a Thermodynamic Unit?
#
# 4. What is a Thermodynamic Unit?
#
# 5. What is a Thermodynamic Unit?
#
# 6. What is a Thermodynamic Unit?
#
# 7. What is a Thermodynamic Unit?
#
# 8. What is a Thermodynamic Unit?
#
# 9. What is a Thermodynamic Unit?
#
# 10. What is a Thermodynamic Unit?
#
# 11. What is a Thermodynamic Unit?
#
# 12. What is a
#
# Q2: Generate 5 medium level questions on Thermodynamics:
#
# 1. What is a Thermodynamic Unit?
#
# 2. What is a Thermodynamic Unit?
#
# 3. What is a Thermodynamic Unit?
#
# 4. What is a Thermodynamic Unit?
#
# 5. What is a Thermodynamic Unit?
#
# 6. What is a Thermodynamic Unit?
#
# 7. What is a Thermodynamic Unit?
#
# 8. What is a Thermodynamic Unit?
#
# 9. What is a Thermodynamic Unit?
#
# 10. What is a Thermodynamic Unit?
#
# ...

# %%
pip install transformers datasets torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import requests
import json

def fetch_quiz_data(amount=10, difficulty="medium", category=9, type="multiple"):
    url = f"https://opentdb.com/api.php?amount={amount}&difficulty={difficulty}&category={category}&type={type}"
    response = requests.get(url)
    data = response.json()
    return data['results'] if data['response_code'] == 0 else []

quiz_data = fetch_quiz_data()
print(json.dumps(quiz_data, indent=4))  # View the raw data
# Out:
# [
#     {
#         "type": "multiple",
#         "difficulty": "medium",
#         "category": "General Knowledge",
#         "question": "Which American manufactured submachine gun was informally known by the American soldiers that used it as &quot;Grease Gun&quot;?",
#         "correct_answer": "M3",
#         "incorrect_answers": [
#             "Colt 9mm",
#             "Thompson",
#             "MAC-10"
#         ]
#     },
#     {
#         "type": "multiple",
#         "difficulty": "medium",
#         "category": "General Knowledge",
#         "question": "The architect known as Le Corbusier was an important figure in what style of architecture?",
#         "correct_answer": "Modernism",
#         "incorrect_answers": [
#             "Neoclassical",
#             "Baroque",
#             "Gothic Revival"
#         ]
#     },
#     {
#         "type": "multiple",
#         "difficulty": "medium",
#         "category": "General Knowledge",
# ...

# %%
from datasets import Dataset
import pandas as pd

# Convert OpenTDB data to a format suitable for training
def prepare_data(quiz_data):
    formatted_data = []
    for item in quiz_data:
        formatted_data.append({
            "input_text": f"Generate a {item['difficulty']} question about {item['category']}",
            "target_text": item["question"]
        })
    return formatted_data

formatted_data = prepare_data(quiz_data)

# Convert to Hugging Face dataset
df = pd.DataFrame(formatted_data)
dataset = Dataset.from_pandas(df)

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments

model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

def tokenize_function(example):
    return tokenizer(example["input_text"], padding="max_length", truncation=True, max_length=512)

tokenized_dataset = dataset.map(tokenize_function, batched=True)

training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

trainer.train()
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ...

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments

model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

def tokenize_function(example):
    # Tokenize both input and target text
    inputs = tokenizer(example["input_text"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")
    targets = tokenizer(example["target_text"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")

    # Prepare the input for the model
    input_ids = inputs.input_ids.squeeze()  # Remove batch dimension if it's 1
    attention_mask = inputs.attention_mask.squeeze()
    labels = targets.input_ids.squeeze()  # Use target text as labels

    # Replace padding token IDs with -100 so they are ignored in loss calculation
    labels[labels == tokenizer.pad_token_id] = -100

    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels,  # Provide labels for the decoder
    }

tokenized_dataset = dataset.map(tokenize_function, batched=False, remove_columns=['input_text', 'target_text']) # batched=False, remove_columns

training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

trainer.train()
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:04, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6, training_loss=6.294822057088216, metrics={'train_runtime': 5.16, 'train_samples_per_second': 5.814, 'train_steps_per_second': 1.163, 'total_flos': 4060254044160.0, 'train_loss': 6.294822057088216, 'epoch': 3.0})

# %%
pip install fastapi uvicorn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import random

app = FastAPI()

# Load the fine-tuned model
tokenizer = T5Tokenizer.from_pretrained("./results")
model = T5ForConditionalGeneration.from_pretrained("./results")

# Sample quiz data
quiz_store = {}

class QuizRequest(BaseModel):
    topic: str
    difficulty: str
    num_questions: int

class AnswerRequest(BaseModel):
    question_id: str
    answer: str

@app.post("/generate_quiz/")
def generate_quiz(request: QuizRequest):
    questions = []
    for _ in range(request.num_questions):
        input_text = f"Generate a {request.difficulty} question about {request.topic}"
        input_ids = tokenizer(input_text, return_tensors="pt").input_ids
        output_ids = model.generate(input_ids)
        question = tokenizer.decode(output_ids[0], skip_special_tokens=True)

        question_id = str(random.randint(1000, 9999))
        correct_answer = "Sample Correct Answer"  # Replace with model-generated answer

        quiz_store[question_id] = correct_answer
        questions.append({"id": question_id, "question": question})

    return {"questions": questions}

@app.post("/submit_answer/")
def submit_answer(request: AnswerRequest):
    correct_answer = quiz_store.get(request.question_id)
    if not correct_answer:
        return {"error": "Invalid question ID"}

    is_correct = request.answer.lower() == correct_answer.lower()
    return {"correct": is_correct, "correct_answer": correct_answer}

# Run using: uvicorn app:app --reload
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-86fd36744f84> in <cell line: 0>()
#       6
#       7 # Load the fine-tuned model
# ----> 8 tokenizer = T5Tokenizer.from_pretrained("./results")
#       9 model = T5ForConditionalGeneration.from_pretrained("./results")
#      10
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2018         # loaded directly from the GGUF file.
#    2019         if all(full_file_name is None for full_file_name in resolved_vocab_files.values()) and not gguf_file:
# -> 2020             raise EnvironmentError(
#    2021                 f"Can't load tokenizer for '{pretrained_model_name_or_path}'. If you were trying to load it from "
# ...

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import random

app = FastAPI()

# Load the fine-tuned model
# Changed to load from the original model name instead of ./results
tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained(".//content/results/checkpoint-2")

# Sample quiz data
quiz_store = {}

class QuizRequest(BaseModel):
    topic: str
    difficulty: str
    num_questions: int

class AnswerRequest(BaseModel):
    question_id: str
    answer: str

@app.post("/generate_quiz/")
def generate_quiz(request: QuizRequest):
    questions = []
    for _ in range(request.num_questions):
        input_text = f"Generate a {request.difficulty} question about {request.topic}"
        input_ids = tokenizer(input_text, return_tensors="pt").input_ids
        output_ids = model.generate(input_ids)
        question = tokenizer.decode(output_ids[0], skip_special_tokens=True)

        question_id = str(random.randint(1000, 9999))
        correct_answer = "Sample Correct Answer"  # Replace with model-generated answer

        quiz_store[question_id] = correct_answer
        questions.append({"id": question_id, "question": question})

    return {"questions": questions}

@app.post("/submit_answer/")
def submit_answer(request: AnswerRequest):
    correct_answer = quiz_store.get(request.question_id)
    if not correct_answer:
        return {"error": "Invalid question ID"}

    is_correct = request.answer.lower() == correct_answer.lower()
    return {"correct": is_correct, "correct_answer": correct_answer}

# Run using: uvicorn app:app --reload
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     402         # Load from URL or cache if already cached
# --> 403         resolved_file = hf_hub_download(
#     404             path_or_repo_id,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     105             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106                 validate_repo_id(arg_value)
#     107
#
# ...

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import random

app = FastAPI()

# Load the fine-tuned model
# Corrected path to the fine-tuned model directory
tokenizer = T5Tokenizer.from_pretrained("./results")
model = T5ForConditionalGeneration.from_pretrained("./results")

# Sample quiz data
quiz_store = {}

class QuizRequest(BaseModel):
    topic: str
    difficulty: str
    num_questions: int

class AnswerRequest(BaseModel):
    question_id: str
    answer: str

@app.post("/generate_quiz/")
def generate_quiz(request: QuizRequest):
    questions = []
    for _ in range(request.num_questions):
        input_text = f"Generate a {request.difficulty} question about {request.topic}"
        input_ids = tokenizer(input_text, return_tensors="pt").input_ids
        output_ids = model.generate(input_ids)
        question = tokenizer.decode(output_ids[0], skip_special_tokens=True)

        question_id = str(random.randint(1000, 9999))
        correct_answer = "Sample Correct Answer"  # Replace with model-generated answer

        quiz_store[question_id] = correct_answer
        questions.append({"id": question_id, "question": question})

    return {"questions": questions}

@app.post("/submit_answer/")
def submit_answer(request: AnswerRequest):
    correct_answer = quiz_store.get(request.question_id)
    if not correct_answer:
        return {"error": "Invalid question ID"}

    is_correct = request.answer.lower() == correct_answer.lower()
    return {"correct": is_correct, "correct_answer": correct_answer}

# Run using: uvicorn app:app --reload
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-41-b17e4037a280> in <cell line: 0>()
#       7 # Load the fine-tuned model
#       8 # Corrected path to the fine-tuned model directory
# ----> 9 tokenizer = T5Tokenizer.from_pretrained("./results")
#      10 model = T5ForConditionalGeneration.from_pretrained("./results")
#      11
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2018         # loaded directly from the GGUF file.
#    2019         if all(full_file_name is None for full_file_name in resolved_vocab_files.values()) and not gguf_file:
# -> 2020             raise EnvironmentError(
# ...

# %%
uvicorn app:app --host 0.0.0.0 --port 8000 --reload
